# %%
import pandas as pd

# %%
pd.read_parquet("initial-data/math.stackexchange.com/file-01.parquet")
# Out:
# /Users/brad/anaconda3/lib/python3.6/site-packages/pyarrow/pandas_compat.py:708: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels = getattr(columns, 'labels', None) or [
# /Users/brad/anaconda3/lib/python3.6/site-packages/pyarrow/pandas_compat.py:735: FutureWarning: the 'labels' keyword is deprecated, use 'codes' instead
#   return pd.MultiIndex(levels=new_levels, labels=labels, names=columns.names)
# /Users/brad/anaconda3/lib/python3.6/site-packages/pyarrow/pandas_compat.py:752: FutureWarning: .labels was deprecated in version 0.24.0. Use .codes instead.
#   labels, = index.labels
#                                                       Body  \
# 0        <p>Can someone explain to me how there can be ...
# 1        <p><a href="http://mathfactor.uark.edu/">mathf...
# 3        <p>I have read a few proofs that $\sqrt{2}$ is...
# 4        <p>I'm looking for a nice, quick online graphi...
# 6        <p>I was reading up on the Fibonacci Sequence,...
# ...

# %%
import json
import time
from datetime import datetime
import pandas as pd

# %%
## start time
t0 = time.time()
print("Start time:", datetime.now().time())

df = pd.read_csv(r'initial-data/file-000000000000.csv')

## end time
T = time.time() - t0;
print("Time taken:", round(T/60), "minutes.")
# Out:
# Start time: 12:36:05.847279
# Time taken: 0 minutes.

# %%
df
# Out:
#          y_score                                               body  \
# 0      -0.002710  <p>I have created a laravel app where I am loa...
# 1       0.000000  <p>I want to use <strong>izitoast.d.ts</strong...
# 2       0.003326  <p>I'm using Grails 3.0.7 and Postgres 9.2. I'...
# 3       0.002791  <p>I am trying to use a RestSharp coding sampl...
# 4       0.000000  <p>I am a web developer working on Mac. Despit...
# 5       0.000000  <p>To comply with the cookies law, I have crea...
# 6       0.000163  <p>I'm just practicing some MIT java assignmen...
# 7       0.005831  <p>i want with underscore remove from a collec...
# 8       0.006110  <p>I am working with pyspark with a schema com...
# 9       0.000000  <p>I have to put a number in state (1400000) a...
# 10      0.000000  <p>If the Action on Google times out, for what...
# 11      0.000812  <p>With golang code I have to transfer file to...
# 12      0.024390  <p>In Haskell with the type families extension...
# ...

# %%
## start time
t0 = time.time()
print("Start time:", datetime.now().time())

#data = json.load(open('initial-data/file-000000000000.json', 'r'))
data = read.csv(open('initial-data/file-000000000000.json', 'r'))

## end time
T = time.time() - t0;
print("Time taken:", round(T/60), "minutes.")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-4-c5c083ead898> in <module>
# ----> 1 data = json.load(open('initial-data/file-000000000000.json', 'r'))
#
# ~/anaconda3/lib/python3.7/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
# --> 296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# ...
